# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
df = pd.read_csv('listings.csv', low_memory=False, na_values = 'NaN')
df2 = pd.read_csv('reviews.csv', na_values = 'NaN')

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2['Year'] = df2['date'].dt.strftime('%Y')

# %%
df.isna().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               10304
# Length: 75, dtype: int64

# %%
df = df.drop(['reviews_per_month'], axis=1)

# %%
df2.isna().sum()
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      4
# comments         220
# Year               0
# dtype: int64

# %%
df2 = df2.drop(['reviewer_name', 'comments'], axis=1)

# %%
df.shape
# Out:
# (42931, 74)

# %%
df2.shape
# Out:
# (1110024, 5)

# %%
df3 = df2.merge(df, how = 'inner', right_on = 'id', left_on = 'listing_id')

# %%
df3.shape
# Out:
# (1110024, 79)

# %%
df3.isna().sum()
# Out:
# listing_id                                      0
# id_x                                            0
# date                                            0
# reviewer_id                                     0
# Year                                            0
#                                                ..
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# Length: 79, dtype: int64

# %%
df3 = df3.drop(['listing_id','listing_url','scrape_id','last_scraped',
                'source','description','neighborhood_overview','picture_url',
                'host_id','id_y','date','reviewer_id'], axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1110024 entries, 0 to 1110023
# Data columns (total 67 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   id_x                                          1110024 non-null  int64
#  1   Year                                          1110024 non-null  object
#  2   name                                          1109990 non-null  object
#  3   host_url                                      1110024 non-null  object
#  4   host_name                                     1110021 non-null  object
#  5   host_since                                    1110021 non-null  object
#  6   host_location                                 965084 non-null   object
#  7   host_about                                    761077 non-null   object
#  8   host_response_time                            931199 non-null   object
#  9   host_response_rate                            931199 non-null   object
#  10  host_acceptance_rate                          978210 non-null   object
#  11  host_is_superhost                             1108203 non-null  object
#  12  host_thumbnail_url                            1110021 non-null  object
#  13  host_picture_url                              1110021 non-null  object
#  14  host_neighbourhood                            933740 non-null   object
#  15  host_listings_count                           1110021 non-null  float64
#  16  host_total_listings_count                     1110021 non-null  float64
#  17  host_verifications                            1110024 non-null  object
#  18  host_has_profile_pic                          1110021 non-null  object
#  19  host_identity_verified                        1110021 non-null  object
#  20  neighbourhood                                 841050 non-null   object
#  21  neighbourhood_cleansed                        1110024 non-null  object
#  22  neighbourhood_group_cleansed                  1110024 non-null  object
#  23  latitude                                      1110024 non-null  float64
#  24  longitude                                     1110024 non-null  float64
#  25  property_type                                 1110024 non-null  object
#  26  room_type                                     1110024 non-null  object
#  27  accommodates                                  1110024 non-null  int64
#  28  bathrooms                                     0 non-null        float64
#  29  bathrooms_text                                1107669 non-null  object
#  30  bedrooms                                      1011678 non-null  float64
#  31  beds                                          1093901 non-null  float64
#  32  amenities                                     1110024 non-null  object
#  33  price                                         1110024 non-null  object
#  34  minimum_nights                                1110024 non-null  int64
#  35  maximum_nights                                1110024 non-null  int64
#  36  minimum_minimum_nights                        1109403 non-null  float64
#  37  maximum_minimum_nights                        1109403 non-null  float64
#  38  minimum_maximum_nights                        1109403 non-null  float64
#  39  maximum_maximum_nights                        1109403 non-null  float64
#  40  minimum_nights_avg_ntm                        1109403 non-null  float64
#  41  maximum_nights_avg_ntm                        1109403 non-null  float64
#  42  calendar_updated                              0 non-null        float64
#  43  has_availability                              1110024 non-null  object
#  44  availability_30                               1110024 non-null  int64
#  45  availability_60                               1110024 non-null  int64
#  46  availability_90                               1110024 non-null  int64
#  47  availability_365                              1110024 non-null  int64
#  48  calendar_last_scraped                         1110024 non-null  object
#  49  number_of_reviews                             1110024 non-null  int64
#  50  number_of_reviews_ltm                         1110024 non-null  int64
#  51  number_of_reviews_l30d                        1110024 non-null  int64
#  52  first_review                                  1110024 non-null  object
#  53  last_review                                   1110024 non-null  object
#  54  review_scores_rating                          1110024 non-null  float64
#  55  review_scores_accuracy                        1109491 non-null  float64
#  56  review_scores_cleanliness                     1109503 non-null  float64
#  57  review_scores_checkin                         1109485 non-null  float64
#  58  review_scores_communication                   1109497 non-null  float64
#  59  review_scores_location                        1109479 non-null  float64
#  60  review_scores_value                           1109479 non-null  float64
#  61  license                                       1 non-null        object
#  62  instant_bookable                              1110024 non-null  object
#  63  calculated_host_listings_count                1110024 non-null  int64
#  64  calculated_host_listings_count_entire_homes   1110024 non-null  int64
#  65  calculated_host_listings_count_private_rooms  1110024 non-null  int64
#  66  calculated_host_listings_count_shared_rooms   1110024 non-null  int64
# dtypes: float64(21), int64(15), object(31)
# memory usage: 575.9+ MB

# %%
df3['Year'] = df3['Year'].astype('float')

# %%
df3 = df3.rename(columns={'neighbourhood_group_cleansed' : 'boroughs'})

# %%
# df3.corr()['price']
df3.corr()['review_scores_rating']
# Out:
# id_x                                            0.003743
# Year                                            0.021656
# host_listings_count                            -0.049685
# host_total_listings_count                      -0.060002
# latitude                                       -0.072668
# longitude                                       0.015420
# accommodates                                    0.005167
# bathrooms                                            NaN
# bedrooms                                        0.030390
# beds                                            0.017320
# minimum_nights                                 -0.033643
# maximum_nights                                 -0.007634
# minimum_minimum_nights                         -0.038693
# maximum_minimum_nights                         -0.035459
# minimum_maximum_nights                         -0.046222
# maximum_maximum_nights                         -0.042819
# minimum_nights_avg_ntm                         -0.035367
# maximum_nights_avg_ntm                         -0.043594
# calendar_updated                                     NaN
# availability_30                                -0.089787
# availability_60                                -0.108026
# availability_90                                -0.110601
# availability_365                               -0.087578
# number_of_reviews                              -0.025803
# number_of_reviews_ltm                          -0.058884
# number_of_reviews_l30d                         -0.084252
# review_scores_rating                            1.000000
# review_scores_accuracy                          0.870621
# review_scores_cleanliness                       0.797628
# review_scores_checkin                           0.731911
# review_scores_communication                     0.773543
# review_scores_location                          0.448677
# review_scores_value                             0.864251
# calculated_host_listings_count                 -0.113552
# calculated_host_listings_count_entire_homes    -0.061824
# calculated_host_listings_count_private_rooms   -0.088727
# calculated_host_listings_count_shared_rooms    -0.057739
# boroughs_Brooklyn                               0.115170
# boroughs_Manhattan                             -0.129146
# boroughs_Queens                                 0.003650
# boroughs_Staten Island                          0.024993
# Name: review_scores_rating, dtype: float64

# %%
df_corr = df3[['accommodates','bathrooms','bedrooms',
               'beds','minimum_nights','maximum_nights',
               'availability_365','number_of_reviews',
               'bathrooms', 'review_scores_rating','review_scores_accuracy',
               'review_scores_cleanliness',]]

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.gca()
df_corr.corr().hist(ax = ax)
plt.show()
# Out:
# C:\Users\mikon\AppData\Local\Temp\ipykernel_22332\3810136485.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df_corr.corr().hist(ax = ax)

# %%
df3[['review_scores_cleanliness','review_scores_checkin',
     'review_scores_accuracy','review_scores_communication']].isna().sum()
# Out:
# review_scores_cleanliness      521
# review_scores_checkin          539
# review_scores_accuracy         533
# review_scores_communication    527
# dtype: int64

# %%
df4 = df3[['review_scores_cleanliness','review_scores_checkin','review_scores_rating',
           'review_scores_accuracy','review_scores_communication']].dropna()

# %%
plt.figure(figsize=(9,8))
cor = df4.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.RdYlBu)
plt.show()

# %%
Y = df4['review_scores_rating']

# %%
df4 = df4[['review_scores_cleanliness','review_scores_checkin','review_scores_accuracy','review_scores_communication']]

# %%
df4.isna().sum()
# Out:
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_accuracy         0
# review_scores_communication    0
# dtype: int64

# %%
train = df3.loc[df3['Year'] < 2017].copy()
test = df3.loc[df3['Year'] >= 2017].copy()

# %%
model = LinearRegression()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1110024 entries, 0 to 1110023
# Data columns (total 70 columns):
#  #   Column                                        Non-Null Count    Dtype
# ---  ------                                        --------------    -----
#  0   id_x                                          1110024 non-null  int64
#  1   Year                                          1110024 non-null  float64
#  2   name                                          1109990 non-null  object
#  3   host_url                                      1110024 non-null  object
#  4   host_name                                     1110021 non-null  object
#  5   host_since                                    1110021 non-null  object
#  6   host_location                                 965084 non-null   object
#  7   host_about                                    761077 non-null   object
#  8   host_response_time                            931199 non-null   object
#  9   host_response_rate                            931199 non-null   object
#  10  host_acceptance_rate                          978210 non-null   object
#  11  host_is_superhost                             1108203 non-null  object
#  12  host_thumbnail_url                            1110021 non-null  object
#  13  host_picture_url                              1110021 non-null  object
#  14  host_neighbourhood                            933740 non-null   object
#  15  host_listings_count                           1110021 non-null  float64
#  16  host_total_listings_count                     1110021 non-null  float64
#  17  host_verifications                            1110024 non-null  object
#  18  host_has_profile_pic                          1110021 non-null  object
#  19  host_identity_verified                        1110021 non-null  object
#  20  neighbourhood                                 841050 non-null   object
#  21  neighbourhood_cleansed                        1110024 non-null  object
#  22  latitude                                      1110024 non-null  float64
#  23  longitude                                     1110024 non-null  float64
#  24  property_type                                 1110024 non-null  object
#  25  room_type                                     1110024 non-null  object
#  26  accommodates                                  1110024 non-null  int64
#  27  bathrooms                                     0 non-null        float64
#  28  bathrooms_text                                1107669 non-null  object
#  29  bedrooms                                      1011678 non-null  float64
#  30  beds                                          1093901 non-null  float64
#  31  amenities                                     1110024 non-null  object
#  32  price                                         1110024 non-null  object
#  33  minimum_nights                                1110024 non-null  int64
#  34  maximum_nights                                1110024 non-null  int64
#  35  minimum_minimum_nights                        1109403 non-null  float64
#  36  maximum_minimum_nights                        1109403 non-null  float64
#  37  minimum_maximum_nights                        1109403 non-null  float64
#  38  maximum_maximum_nights                        1109403 non-null  float64
#  39  minimum_nights_avg_ntm                        1109403 non-null  float64
#  40  maximum_nights_avg_ntm                        1109403 non-null  float64
#  41  calendar_updated                              0 non-null        float64
#  42  has_availability                              1110024 non-null  object
#  43  availability_30                               1110024 non-null  int64
#  44  availability_60                               1110024 non-null  int64
#  45  availability_90                               1110024 non-null  int64
#  46  availability_365                              1110024 non-null  int64
#  47  calendar_last_scraped                         1110024 non-null  object
#  48  number_of_reviews                             1110024 non-null  int64
#  49  number_of_reviews_ltm                         1110024 non-null  int64
#  50  number_of_reviews_l30d                        1110024 non-null  int64
#  51  first_review                                  1110024 non-null  object
#  52  last_review                                   1110024 non-null  object
#  53  review_scores_rating                          1110024 non-null  float64
#  54  review_scores_accuracy                        1109491 non-null  float64
#  55  review_scores_cleanliness                     1109503 non-null  float64
#  56  review_scores_checkin                         1109485 non-null  float64
#  57  review_scores_communication                   1109497 non-null  float64
#  58  review_scores_location                        1109479 non-null  float64
#  59  review_scores_value                           1109479 non-null  float64
#  60  license                                       1 non-null        object
#  61  instant_bookable                              1110024 non-null  object
#  62  calculated_host_listings_count                1110024 non-null  int64
#  63  calculated_host_listings_count_entire_homes   1110024 non-null  int64
#  64  calculated_host_listings_count_private_rooms  1110024 non-null  int64
#  65  calculated_host_listings_count_shared_rooms   1110024 non-null  int64
#  66  boroughs_Brooklyn                             1110024 non-null  uint8
#  67  boroughs_Manhattan                            1110024 non-null  uint8
#  68  boroughs_Queens                               1110024 non-null  uint8
#  69  boroughs_Staten Island                        1110024 non-null  uint8
# dtypes: float64(22), int64(15), object(29), uint8(4)
# memory usage: 571.6+ MB

# %%
X = df4[['review_scores_cleanliness','review_scores_checkin','review_scores_accuracy','review_scores_communication']]

# %%
Y.shape
# Out:
# (1109485,)

# %%
X.shape
# Out:
# (1109485, 4)

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y)
# Out:
# 0.8458227994944221

# %%
results = train_test_split(X, Y, random_state=42, test_size=0.4 )
X_train, X_test, Y_train, Y_test = results
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((665691, 4), (443794, 4), (665691,), (443794,))

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
print(model.score(X_train, Y_train))
print(model.score(X_test, Y_test))
# Out:
# 0.8459298649740412
# 0.8456248732884555

# %%
mean_absolute_error(Y_test, model.predict(X_test))
# Out:
# 0.053670640102365844

# %%
mean_squared_error(Y_test, model.predict(X_test))
# Out:
# 0.006852090200408932

# %%
model.score(X_test, Y_test)
# Out:
# 0.8456248732884555

# %%
predictions = model.predict(X_test)

# %%
r2_score(Y_test, model.predict(X_test))
# Out:
# 0.8456248732884555

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(18,12))
x_ax = range(len(Y_test))
plt.scatter(x_ax, Y_test, label="original")
plt.scatter(x_ax,predictions, label="predicted")
plt.title("Actual Ratings and predicted data")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(Y_test, predictions,alpha = 0.03)
plt.plot([0,5],[0,5],linestyle='--', color='red')
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
ax.set_title('Actual Review Rating vs. Predicted')
plt.xlim(3,5.1)
plt.ylim(3,5.1)
# Out:
# (3.0, 5.1)

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
# plt.figure(figsize=(12,6))
# plt.scatter(df4['review_scores_cleanliness'], Y)
# # plt.plot(df4['review_scores_cleanliness'], Y_predict, 'r')
# plt.show()
